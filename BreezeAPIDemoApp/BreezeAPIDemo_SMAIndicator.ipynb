# %% [markdown]
# # BreezeAPI Options Strategy

# %% [markdown]
# ## Install BreezeAPI package

# %%
pip install --upgrade breeze-connect
# Out:
# Requirement already satisfied: breeze-connect in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.0.48)Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: breeze-connect is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: C:\Users\jigar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting breeze-connect
#   Downloading breeze_connect-1.0.53.tar.gz (35 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: python-socketio[client] in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from breeze-connect) (5.10.0)
# Requirement already satisfied: requests in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from breeze-connect) (2.31.0)
# Requirement already satisfied: pandas in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from breeze-connect) (2.1.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->breeze-connect) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->breeze-connect) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->breeze-connect) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->breeze-connect) (2023.3)
# Requirement already satisfied: python-engineio>=4.8.0 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-socketio[client]->breeze-connect) (4.8.0)
# Requirement already satisfied: bidict>=0.21.0 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-socketio[client]->breeze-connect) (0.22.1)
# Requirement already satisfied: websocket-client>=0.54.0 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-socketio[client]->breeze-connect) (1.6.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->breeze-connect) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->breeze-connect) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->breeze-connect) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->breeze-connect) (2.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.2->pandas->breeze-connect) (1.16.0)
# Requirement already satisfied: simple-websocket>=0.10.0 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-engineio>=4.8.0->python-socketio[client]->breeze-connect) (1.0.0)
# Requirement already satisfied: wsproto in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio[client]->breeze-connect) (1.2.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio[client]->breeze-connect) (0.14.0)
# Installing collected packages: breeze-connect
#   Attempting uninstall: breeze-connect
#     Found existing installation: breeze_connect 1.0.48
#     Uninstalling breeze_connect-1.0.48:
#       Successfully uninstalled breeze_connect-1.0.48
#   Running setup.py install for breeze-connect: started
#   Running setup.py install for breeze-connect: finished with status 'done'
# Successfully installed breeze-connect-1.0.53

# %%
pip install --upgrade mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.10b0-py3-none-any.whl (75 kB)
#      ---------------------------------------- 0.0/75.0 kB ? eta -:--:--
#      -------------------- ----------------- 41.0/75.0 kB 991.0 kB/s eta 0:00:01
#      ---------------------------------------- 75.0/75.0 kB 1.4 MB/s eta 0:00:00
# Collecting matplotlib
#   Downloading matplotlib-3.8.4-cp310-cp310-win_amd64.whl (7.7 MB)
#      ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#       --------------------------------------- 0.1/7.7 MB 3.5 MB/s eta 0:00:03
#      -- ------------------------------------- 0.4/7.7 MB 5.4 MB/s eta 0:00:02
#      --- ------------------------------------ 0.7/7.7 MB 5.7 MB/s eta 0:00:02
#      -------- ------------------------------- 1.7/7.7 MB 9.8 MB/s eta 0:00:01
#      ------------- -------------------------- 2.6/7.7 MB 11.7 MB/s eta 0:00:01
#      --------------- ------------------------ 3.0/7.7 MB 13.6 MB/s eta 0:00:01
#      --------------- ------------------------ 3.0/7.7 MB 13.6 MB/s eta 0:00:01
#      ------------------------ --------------- 4.6/7.7 MB 13.4 MB/s eta 0:00:01
#      ------------------------- -------------- 4.9/7.7 MB 12.6 MB/s eta 0:00:01
#      ---------------------------- ----------- 5.5/7.7 MB 12.6 MB/s eta 0:00:01
#      --------------------------------- ------ 6.4/7.7 MB 13.6 MB/s eta 0:00:01
#      ------------------------------------- -- 7.1/7.7 MB 13.3 MB/s eta 0:00:01
#      -------------------------------------- - 7.5/7.7 MB 13.2 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.7 MB 12.5 MB/s eta 0:00:01
#      ---------------------------------------- 7.7/7.7 MB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from mplfinance) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: numpy>=1.21 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->mplfinance) (1.26.2)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
#      ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#      ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.51.0-cp310-cp310-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#      ------------- -------------------------- 0.7/2.2 MB 23.8 MB/s eta 0:00:01
#      --------------------------- ------------ 1.5/2.2 MB 19.2 MB/s eta 0:00:01
#      ---------------------------------------  2.2/2.2 MB 19.7 MB/s eta 0:00:01
#      ---------------------------------------- 2.2/2.2 MB 17.4 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.1-cp310-cp310-win_amd64.whl (187 kB)
#      ---------------------------------------- 0.0/187.5 kB ? eta -:--:--
#      ------------------------------------- 187.5/187.5 kB 11.8 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#      ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#      -------------------------------------- 103.2/103.2 kB 6.2 MB/s eta 0:00:00
# Collecting pillow>=8
#   Downloading pillow-10.3.0-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ------------- -------------------------- 0.8/2.5 MB 26.2 MB/s eta 0:00:01
#      --------------------------- ------------ 1.8/2.5 MB 22.0 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 20.2 MB/s eta 0:00:01
#      ---------------------------------------- 2.5/2.5 MB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->mplfinance) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->mplfinance) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, mplfinance
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 kiwisolver-1.4.5 matplotlib-3.8.4 mplfinance-0.12.10b0 pillow-10.3.0 pyparsing-3.1.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: C:\Users\jigar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install --upgrade matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.8.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: numpy>=1.21 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: pillow>=8 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: C:\Users\jigar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Import required packages

# %%
from breeze_connect import BreezeConnect
from datetime import datetime
import urllib
import numpy as np
import pandas as pd

import mplfinance as mpf
import matplotlib.pyplot as plt

# %% [markdown]
# ## Variables for initial setup

# %%
Api_key="^42y6975650632#94258t282@r718`77"
Api_Secret="i0td81HE339202156w96102D98497633"

# %% [markdown]
# ## Get Link to generate session key

# %%
print("https://api.icicidirect.com/apiuser/login?api_key="+urllib.parse.quote_plus(Api_key))
# Out:
# https://api.icicidirect.com/apiuser/login?api_key=%5E42y6975650632%2394258t282%40r718%6077

# %% [markdown]
# ## Declare Session key variable

# %%
Api_Session="39239336"

# %% [markdown]
# ## Initialize SDK

# %%
breeze = BreezeConnect(api_key=Api_key)

# %% [markdown]
# ## Generate Session

# %%
breeze.generate_session(api_secret=Api_Secret,
                        session_token=Api_Session)

# %% [markdown]
# ## Indicator process

# %%
data=breeze.get_historical_data_v2(interval="1day",
                            from_date= "2023-12-01T07:00:00.000Z",
                            to_date= "2024-04-22T07:00:00.000Z",
                            stock_code="NIFTY",
                            exchange_code="NSE",
                            product_type="cash",
                            expiry_date="2022-08-25T07:00:00.000Z",
                            right="others",
                            strike_price="0")["Success"]

# %%
data
# Out:
# [{'close': 20686.8,
#   'datetime': '2023-12-04 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 20702.25,
#   'low': 20508.65,
#   'open': 20601.95,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 20856.7,
#   'datetime': '2023-12-05 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 20863.7,
#   'low': 20711.15,
#   'open': 20808.9,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 20935.9,
#   'datetime': '2023-12-06 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 20961.45,
#   'low': 20852.8,
#   'open': 20950.75,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 20916.1,
#   'datetime': '2023-12-07 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 20935.85,
#   'low': 20851.45,
#   'open': 20932.4,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 20972.1,
#   'datetime': '2023-12-08 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21005.75,
#   'low': 20863.05,
#   'open': 20934.1,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21000.05,
#   'datetime': '2023-12-11 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21025.6,
#   'low': 20932.0,
#   'open': 20965.3,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 20900.4,
#   'datetime': '2023-12-12 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21037.85,
#   'low': 20867.65,
#   'open': 21018.55,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 20937.45,
#   'datetime': '2023-12-13 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 20949.15,
#   'low': 20769.85,
#   'open': 20929.75,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21195.25,
#   'datetime': '2023-12-14 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21210.75,
#   'low': 21081.1,
#   'open': 21110.4,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21448.7,
#   'datetime': '2023-12-15 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21490.5,
#   'low': 21235.5,
#   'open': 21287.45,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21410.8,
#   'datetime': '2023-12-18 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21482.7,
#   'low': 21365.85,
#   'open': 21434.8,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21446.0,
#   'datetime': '2023-12-19 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21504.5,
#   'low': 21338.5,
#   'open': 21477.65,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21101.5,
#   'datetime': '2023-12-20 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21592.1,
#   'low': 21088.55,
#   'open': 21543.5,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21283.0,
#   'datetime': '2023-12-21 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21287.8,
#   'low': 20979.8,
#   'open': 21033.95,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21332.35,
#   'datetime': '2023-12-22 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21389.9,
#   'low': 21233.5,
#   'open': 21295.85,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21454.15,
#   'datetime': '2023-12-26 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21476.3,
#   'low': 21329.6,
#   'open': 21365.2,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21648.95,
#   'datetime': '2023-12-27 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21674.95,
#   'low': 21497.65,
#   'open': 21497.65,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21773.7,
#   'datetime': '2023-12-28 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21798.6,
#   'low': 21678.2,
#   'open': 21715.0,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21728.3,
#   'datetime': '2023-12-29 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21762.4,
#   'low': 21677.3,
#   'open': 21728.9,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21689.45,
#   'datetime': '2024-01-01 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21832.4,
#   'low': 21682.75,
#   'open': 21694.25,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21661.5,
#   'datetime': '2024-01-02 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21752.45,
#   'low': 21557.5,
#   'open': 21751.35,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21523.7,
#   'datetime': '2024-01-03 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21672.15,
#   'low': 21501.5,
#   'open': 21661.1,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21669.6,
#   'datetime': '2024-01-04 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21684.8,
#   'low': 21569.25,
#   'open': 21605.8,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21709.55,
#   'datetime': '2024-01-05 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21744.05,
#   'low': 21629.75,
#   'open': 21736.6,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21511.1,
#   'datetime': '2024-01-08 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21763.4,
#   'low': 21493.6,
#   'open': 21747.6,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21552.3,
#   'datetime': '2024-01-09 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21723.7,
#   'low': 21518.05,
#   'open': 21653.6,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21623.8,
#   'datetime': '2024-01-10 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21641.3,
#   'low': 21448.75,
#   'open': 21529.3,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21665.55,
#   'datetime': '2024-01-11 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21725.25,
#   'low': 21594.0,
#   'open': 21688.0,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21908.25,
#   'datetime': '2024-01-12 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21927.2,
#   'low': 21718.75,
#   'open': 21773.55,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22109.8,
#   'datetime': '2024-01-15 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22113.55,
#   'low': 21964.1,
#   'open': 22053.15,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22031.6,
#   'datetime': '2024-01-16 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22123.55,
#   'low': 21971.2,
#   'open': 22080.5,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21577.25,
#   'datetime': '2024-01-17 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21851.15,
#   'low': 21551.5,
#   'open': 21647.25,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21477.25,
#   'datetime': '2024-01-18 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21539.05,
#   'low': 21286.45,
#   'open': 21414.2,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21638.2,
#   'datetime': '2024-01-19 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21670.5,
#   'low': 21576.0,
#   'open': 21615.2,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21586.95,
#   'datetime': '2024-01-20 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21718.5,
#   'low': 21542.05,
#   'open': 21706.15,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21243.05,
#   'datetime': '2024-01-23 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21749.25,
#   'low': 21193.0,
#   'open': 21716.7,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21460.7,
#   'datetime': '2024-01-24 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21481.9,
#   'low': 21137.95,
#   'open': 21185.25,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21370.75,
#   'datetime': '2024-01-25 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21456.9,
#   'low': 21248.15,
#   'open': 21454.6,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21744.8,
#   'datetime': '2024-01-29 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21762.8,
#   'low': 21433.1,
#   'open': 21433.1,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21530.55,
#   'datetime': '2024-01-30 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21811.0,
#   'low': 21502.3,
#   'open': 21775.75,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21708.3,
#   'datetime': '2024-01-31 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21739.35,
#   'low': 21449.65,
#   'open': 21487.25,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21690.3,
#   'datetime': '2024-02-01 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21832.7,
#   'low': 21659.8,
#   'open': 21780.65,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21855.45,
#   'datetime': '2024-02-02 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22125.85,
#   'low': 21805.95,
#   'open': 21812.75,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21761.3,
#   'datetime': '2024-02-05 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21963.4,
#   'low': 21727.5,
#   'open': 21921.05,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21938.8,
#   'datetime': '2024-02-06 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21950.75,
#   'low': 21738.5,
#   'open': 21825.2,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21949.8,
#   'datetime': '2024-02-07 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22051.1,
#   'low': 21860.85,
#   'open': 22045.05,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21759.7,
#   'datetime': '2024-02-08 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22009.95,
#   'low': 21666.0,
#   'open': 22009.65,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21786.0,
#   'datetime': '2024-02-09 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21803.15,
#   'low': 21631.35,
#   'open': 21727.0,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21612.6,
#   'datetime': '2024-02-12 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21830.55,
#   'low': 21575.2,
#   'open': 21800.8,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21728.0,
#   'datetime': '2024-02-13 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21766.45,
#   'low': 21544.4,
#   'open': 21664.3,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21848.7,
#   'datetime': '2024-02-14 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21870.2,
#   'low': 21530.9,
#   'open': 21578.15,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21927.05,
#   'datetime': '2024-02-15 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21952.8,
#   'low': 21796.1,
#   'open': 21906.55,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22035.7,
#   'datetime': '2024-02-16 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22067.5,
#   'low': 21969.55,
#   'open': 22020.3,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22116.95,
#   'datetime': '2024-02-19 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22186.3,
#   'low': 22021.7,
#   'open': 22103.45,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22208.15,
#   'datetime': '2024-02-20 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22214.95,
#   'low': 22046.65,
#   'open': 22099.2,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22028.75,
#   'datetime': '2024-02-21 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22249.2,
#   'low': 21998.0,
#   'open': 22248.85,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22216.9,
#   'datetime': '2024-02-22 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22251.05,
#   'low': 21875.25,
#   'open': 22081.55,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22194.25,
#   'datetime': '2024-02-23 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22297.45,
#   'low': 22187.55,
#   'open': 22290.0,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22117.15,
#   'datetime': '2024-02-26 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22201.25,
#   'low': 22075.7,
#   'open': 22169.2,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22194.2,
#   'datetime': '2024-02-27 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22217.35,
#   'low': 22086.45,
#   'open': 22090.2,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21926.25,
#   'datetime': '2024-02-28 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22228.45,
#   'low': 21918.9,
#   'open': 22214.1,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22042.05,
#   'datetime': '2024-02-29 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22059.8,
#   'low': 21861.35,
#   'open': 21935.2,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22326.05,
#   'datetime': '2024-03-01 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22352.95,
#   'low': 22048.3,
#   'open': 22048.3,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22378.4,
#   'datetime': '2024-03-02 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22463.65,
#   'low': 22367.1,
#   'open': 22406.95,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22397.65,
#   'datetime': '2024-03-04 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22440.9,
#   'low': 22358.9,
#   'open': 22403.5,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22358.5,
#   'datetime': '2024-03-05 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22415.6,
#   'low': 22269.95,
#   'open': 22371.25,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22480.05,
#   'datetime': '2024-03-06 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22493.0,
#   'low': 22225.65,
#   'open': 22327.5,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22483.5,
#   'datetime': '2024-03-07 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22524.0,
#   'low': 22431.1,
#   'open': 22505.3,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22319.85,
#   'datetime': '2024-03-11 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22517.5,
#   'low': 22308.25,
#   'open': 22517.5,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22332.7,
#   'datetime': '2024-03-12 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22451.25,
#   'low': 22256.75,
#   'open': 22334.45,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21981.05,
#   'datetime': '2024-03-13 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22439.7,
#   'low': 21905.75,
#   'open': 22432.2,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22153.05,
#   'datetime': '2024-03-14 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22204.15,
#   'low': 21920.05,
#   'open': 21982.55,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21996.35,
#   'datetime': '2024-03-15 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22120.55,
#   'low': 21931.9,
#   'open': 22064.85,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22051.5,
#   'datetime': '2024-03-18 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22123.5,
#   'low': 21918.25,
#   'open': 21990.1,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21810.35,
#   'datetime': '2024-03-19 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21976.7,
#   'low': 21794.4,
#   'open': 21946.45,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 21855.1,
#   'datetime': '2024-03-20 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 21930.5,
#   'low': 21710.35,
#   'open': 21843.9,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22014.6,
#   'datetime': '2024-03-21 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22080.8,
#   'low': 21941.95,
#   'open': 21989.9,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22080.8,
#   'datetime': '2024-03-22 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22179.0,
#   'low': 21884.15,
#   'open': 21932.2,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22019.8,
#   'datetime': '2024-03-26 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22072.65,
#   'low': 21947.9,
#   'open': 21947.9,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22147.2,
#   'datetime': '2024-03-27 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22193.15,
#   'low': 22053.95,
#   'open': 22053.95,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22343.1,
#   'datetime': '2024-03-28 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22513.2,
#   'low': 22163.6,
#   'open': 22163.6,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22469.05,
#   'datetime': '2024-04-01 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22529.1,
#   'low': 22427.85,
#   'open': 22455.0,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22464.3,
#   'datetime': '2024-04-02 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22496.9,
#   'low': 22389.15,
#   'open': 22458.8,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22445.55,
#   'datetime': '2024-04-03 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22520.9,
#   'low': 22347.8,
#   'open': 22385.7,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22541.2,
#   'datetime': '2024-04-04 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22603.6,
#   'low': 22307.45,
#   'open': 22592.1,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22523.4,
#   'datetime': '2024-04-05 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22536.6,
#   'low': 22429.0,
#   'open': 22486.4,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22661.0,
#   'datetime': '2024-04-08 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22696.95,
#   'low': 22550.35,
#   'open': 22578.35,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22642.05,
#   'datetime': '2024-04-09 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22768.35,
#   'low': 22613.15,
#   'open': 22765.1,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22732.85,
#   'datetime': '2024-04-10 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22775.7,
#   'low': 22674.55,
#   'open': 22720.25,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22519.4,
#   'datetime': '2024-04-12 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22726.15,
#   'low': 22503.85,
#   'open': 22677.4,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22277.45,
#   'datetime': '2024-04-15 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22426.55,
#   'low': 22260.1,
#   'open': 22339.05,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22177.45,
#   'datetime': '2024-04-16 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22213.5,
#   'low': 22079.7,
#   'open': 22125.3,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22045.75,
#   'datetime': '2024-04-18 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22326.25,
#   'low': 21962.0,
#   'open': 22249.55,
#   'stock_code': 'NIFTY',
#   'volume': 0},
#  {'close': 22149.7,
#   'datetime': '2024-04-19 00:00:00',
#   'exchange_code': 'NSE',
#   'high': 22179.3,
#   'low': 21613.3,
#   'open': 21613.3,
#   'stock_code': 'NIFTY',
#   'volume': 18}]

# %%
df=pd.DataFrame(data)
df
# Out:
#        close             datetime exchange_code      high       low      open  \
# 0   20686.80  2023-12-04 00:00:00           NSE  20702.25  20508.65  20601.95
# 1   20856.70  2023-12-05 00:00:00           NSE  20863.70  20711.15  20808.90
# 2   20935.90  2023-12-06 00:00:00           NSE  20961.45  20852.80  20950.75
# 3   20916.10  2023-12-07 00:00:00           NSE  20935.85  20851.45  20932.40
# 4   20972.10  2023-12-08 00:00:00           NSE  21005.75  20863.05  20934.10
# ..       ...                  ...           ...       ...       ...       ...
# 89  22519.40  2024-04-12 00:00:00           NSE  22726.15  22503.85  22677.40
# 90  22277.45  2024-04-15 00:00:00           NSE  22426.55  22260.10  22339.05
# 91  22177.45  2024-04-16 00:00:00           NSE  22213.50  22079.70  22125.30
# 92  22045.75  2024-04-18 00:00:00           NSE  22326.25  21962.00  22249.55
# 93  22149.70  2024-04-19 00:00:00           NSE  22179.30  21613.30  21613.30
#
#    stock_code  volume
# 0       NIFTY       0
# 1       NIFTY       0
# 2       NIFTY       0
# 3       NIFTY       0
# 4       NIFTY       0
# ..        ...     ...
# 89      NIFTY       0
# 90      NIFTY       0
# 91      NIFTY       0
# 92      NIFTY       0
# 93      NIFTY      18
#
# [94 rows x 8 columns]

# %%
df.set_index("datetime")
df.drop(['exchange_code','stock_code','volume'],axis=1, inplace=True)
df.tail()
# Out:
#        close             datetime      high       low      open
# 89  22519.40  2024-04-12 00:00:00  22726.15  22503.85  22677.40
# 90  22277.45  2024-04-15 00:00:00  22426.55  22260.10  22339.05
# 91  22177.45  2024-04-16 00:00:00  22213.50  22079.70  22125.30
# 92  22045.75  2024-04-18 00:00:00  22326.25  21962.00  22249.55
# 93  22149.70  2024-04-19 00:00:00  22179.30  21613.30  21613.30

# %%
df.index=pd.to_datetime(df.index)

mpf.plot(df,type='candle',style='charles',volume=False)

# %%
# SMA
lookback_period=10
df['sma']=df['close'].rolling(lookback_period).mean()

# %%
df.head(20)
# Out:
#                                   close             datetime      high  \
# 1970-01-01 00:00:00.000000000  20686.80  2023-12-04 00:00:00  20702.25
# 1970-01-01 00:00:00.000000001  20856.70  2023-12-05 00:00:00  20863.70
# 1970-01-01 00:00:00.000000002  20935.90  2023-12-06 00:00:00  20961.45
# 1970-01-01 00:00:00.000000003  20916.10  2023-12-07 00:00:00  20935.85
# 1970-01-01 00:00:00.000000004  20972.10  2023-12-08 00:00:00  21005.75
# 1970-01-01 00:00:00.000000005  21000.05  2023-12-11 00:00:00  21025.60
# 1970-01-01 00:00:00.000000006  20900.40  2023-12-12 00:00:00  21037.85
# 1970-01-01 00:00:00.000000007  20937.45  2023-12-13 00:00:00  20949.15
# 1970-01-01 00:00:00.000000008  21195.25  2023-12-14 00:00:00  21210.75
# 1970-01-01 00:00:00.000000009  21448.70  2023-12-15 00:00:00  21490.50
# 1970-01-01 00:00:00.000000010  21410.80  2023-12-18 00:00:00  21482.70
# 1970-01-01 00:00:00.000000011  21446.00  2023-12-19 00:00:00  21504.50
# 1970-01-01 00:00:00.000000012  21101.50  2023-12-20 00:00:00  21592.10
# 1970-01-01 00:00:00.000000013  21283.00  2023-12-21 00:00:00  21287.80
# 1970-01-01 00:00:00.000000014  21332.35  2023-12-22 00:00:00  21389.90
# 1970-01-01 00:00:00.000000015  21454.15  2023-12-26 00:00:00  21476.30
# 1970-01-01 00:00:00.000000016  21648.95  2023-12-27 00:00:00  21674.95
# 1970-01-01 00:00:00.000000017  21773.70  2023-12-28 00:00:00  21798.60
# 1970-01-01 00:00:00.000000018  21728.30  2023-12-29 00:00:00  21762.40
# 1970-01-01 00:00:00.000000019  21689.45  2024-01-01 00:00:00  21832.40
#
#                                     low      open        sma
# 1970-01-01 00:00:00.000000000  20508.65  20601.95        NaN
# 1970-01-01 00:00:00.000000001  20711.15  20808.90        NaN
# 1970-01-01 00:00:00.000000002  20852.80  20950.75        NaN
# 1970-01-01 00:00:00.000000003  20851.45  20932.40        NaN
# 1970-01-01 00:00:00.000000004  20863.05  20934.10        NaN
# 1970-01-01 00:00:00.000000005  20932.00  20965.30        NaN
# 1970-01-01 00:00:00.000000006  20867.65  21018.55        NaN
# 1970-01-01 00:00:00.000000007  20769.85  20929.75        NaN
# 1970-01-01 00:00:00.000000008  21081.10  21110.40        NaN
# 1970-01-01 00:00:00.000000009  21235.50  21287.45  20984.945
# 1970-01-01 00:00:00.000000010  21365.85  21434.80  21057.345
# 1970-01-01 00:00:00.000000011  21338.50  21477.65  21116.275
# 1970-01-01 00:00:00.000000012  21088.55  21543.50  21132.835
# 1970-01-01 00:00:00.000000013  20979.80  21033.95  21169.525
# 1970-01-01 00:00:00.000000014  21233.50  21295.85  21205.550
# 1970-01-01 00:00:00.000000015  21329.60  21365.20  21250.960
# 1970-01-01 00:00:00.000000016  21497.65  21497.65  21325.815
# 1970-01-01 00:00:00.000000017  21678.20  21715.00  21409.440
# 1970-01-01 00:00:00.000000018  21677.30  21728.90  21462.745
# 1970-01-01 00:00:00.000000019  21682.75  21694.25  21486.820

# %%
pip install --upgrade pandas_ta
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: pandas_ta is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: C:\Users\jigar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ---------------------------------------- 0.0/115.1 kB ? eta -:--:--
#      ------------- ----------------------- 41.0/115.1 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------  112.6/115.1 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 115.1/115.1 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas_ta) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->pandas_ta) (1.26.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->pandas_ta) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->pandas_ta) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.2->pandas->pandas_ta) (1.16.0)
# Installing collected packages: pandas_ta
#   Running setup.py install for pandas_ta: started
#   Running setup.py install for pandas_ta: finished with status 'done'
# Successfully installed pandas_ta-0.3.14b0

# %%
import pandas_ta as ta

# %%
df['sma']=ta.sma(df['close'], length=10)
df.head(20)
# Out:
#                                   close             datetime      high  \
# 1970-01-01 00:00:00.000000000  20686.80  2023-12-04 00:00:00  20702.25
# 1970-01-01 00:00:00.000000001  20856.70  2023-12-05 00:00:00  20863.70
# 1970-01-01 00:00:00.000000002  20935.90  2023-12-06 00:00:00  20961.45
# 1970-01-01 00:00:00.000000003  20916.10  2023-12-07 00:00:00  20935.85
# 1970-01-01 00:00:00.000000004  20972.10  2023-12-08 00:00:00  21005.75
# 1970-01-01 00:00:00.000000005  21000.05  2023-12-11 00:00:00  21025.60
# 1970-01-01 00:00:00.000000006  20900.40  2023-12-12 00:00:00  21037.85
# 1970-01-01 00:00:00.000000007  20937.45  2023-12-13 00:00:00  20949.15
# 1970-01-01 00:00:00.000000008  21195.25  2023-12-14 00:00:00  21210.75
# 1970-01-01 00:00:00.000000009  21448.70  2023-12-15 00:00:00  21490.50
# 1970-01-01 00:00:00.000000010  21410.80  2023-12-18 00:00:00  21482.70
# 1970-01-01 00:00:00.000000011  21446.00  2023-12-19 00:00:00  21504.50
# 1970-01-01 00:00:00.000000012  21101.50  2023-12-20 00:00:00  21592.10
# 1970-01-01 00:00:00.000000013  21283.00  2023-12-21 00:00:00  21287.80
# 1970-01-01 00:00:00.000000014  21332.35  2023-12-22 00:00:00  21389.90
# 1970-01-01 00:00:00.000000015  21454.15  2023-12-26 00:00:00  21476.30
# 1970-01-01 00:00:00.000000016  21648.95  2023-12-27 00:00:00  21674.95
# 1970-01-01 00:00:00.000000017  21773.70  2023-12-28 00:00:00  21798.60
# 1970-01-01 00:00:00.000000018  21728.30  2023-12-29 00:00:00  21762.40
# 1970-01-01 00:00:00.000000019  21689.45  2024-01-01 00:00:00  21832.40
#
#                                     low      open        sma
# 1970-01-01 00:00:00.000000000  20508.65  20601.95        NaN
# 1970-01-01 00:00:00.000000001  20711.15  20808.90        NaN
# 1970-01-01 00:00:00.000000002  20852.80  20950.75        NaN
# 1970-01-01 00:00:00.000000003  20851.45  20932.40        NaN
# 1970-01-01 00:00:00.000000004  20863.05  20934.10        NaN
# 1970-01-01 00:00:00.000000005  20932.00  20965.30        NaN
# 1970-01-01 00:00:00.000000006  20867.65  21018.55        NaN
# 1970-01-01 00:00:00.000000007  20769.85  20929.75        NaN
# 1970-01-01 00:00:00.000000008  21081.10  21110.40        NaN
# 1970-01-01 00:00:00.000000009  21235.50  21287.45  20984.945
# 1970-01-01 00:00:00.000000010  21365.85  21434.80  21057.345
# 1970-01-01 00:00:00.000000011  21338.50  21477.65  21116.275
# 1970-01-01 00:00:00.000000012  21088.55  21543.50  21132.835
# 1970-01-01 00:00:00.000000013  20979.80  21033.95  21169.525
# 1970-01-01 00:00:00.000000014  21233.50  21295.85  21205.550
# 1970-01-01 00:00:00.000000015  21329.60  21365.20  21250.960
# 1970-01-01 00:00:00.000000016  21497.65  21497.65  21325.815
# 1970-01-01 00:00:00.000000017  21678.20  21715.00  21409.440
# 1970-01-01 00:00:00.000000018  21677.30  21728.90  21462.745
# 1970-01-01 00:00:00.000000019  21682.75  21694.25  21486.820

# %%
# Calculate EMA
df['ema']=df['close'].ewm(span=9).mean()
df.head(20)
# Out:
#                                   close             datetime      high  \
# 1970-01-01 00:00:00.000000000  20686.80  2023-12-04 00:00:00  20702.25
# 1970-01-01 00:00:00.000000001  20856.70  2023-12-05 00:00:00  20863.70
# 1970-01-01 00:00:00.000000002  20935.90  2023-12-06 00:00:00  20961.45
# 1970-01-01 00:00:00.000000003  20916.10  2023-12-07 00:00:00  20935.85
# 1970-01-01 00:00:00.000000004  20972.10  2023-12-08 00:00:00  21005.75
# 1970-01-01 00:00:00.000000005  21000.05  2023-12-11 00:00:00  21025.60
# 1970-01-01 00:00:00.000000006  20900.40  2023-12-12 00:00:00  21037.85
# 1970-01-01 00:00:00.000000007  20937.45  2023-12-13 00:00:00  20949.15
# 1970-01-01 00:00:00.000000008  21195.25  2023-12-14 00:00:00  21210.75
# 1970-01-01 00:00:00.000000009  21448.70  2023-12-15 00:00:00  21490.50
# 1970-01-01 00:00:00.000000010  21410.80  2023-12-18 00:00:00  21482.70
# 1970-01-01 00:00:00.000000011  21446.00  2023-12-19 00:00:00  21504.50
# 1970-01-01 00:00:00.000000012  21101.50  2023-12-20 00:00:00  21592.10
# 1970-01-01 00:00:00.000000013  21283.00  2023-12-21 00:00:00  21287.80
# 1970-01-01 00:00:00.000000014  21332.35  2023-12-22 00:00:00  21389.90
# 1970-01-01 00:00:00.000000015  21454.15  2023-12-26 00:00:00  21476.30
# 1970-01-01 00:00:00.000000016  21648.95  2023-12-27 00:00:00  21674.95
# 1970-01-01 00:00:00.000000017  21773.70  2023-12-28 00:00:00  21798.60
# 1970-01-01 00:00:00.000000018  21728.30  2023-12-29 00:00:00  21762.40
# 1970-01-01 00:00:00.000000019  21689.45  2024-01-01 00:00:00  21832.40
#
#                                     low      open        sma           ema
# 1970-01-01 00:00:00.000000000  20508.65  20601.95        NaN  20686.800000
# 1970-01-01 00:00:00.000000001  20711.15  20808.90        NaN  20781.188889
# 1970-01-01 00:00:00.000000002  20852.80  20950.75        NaN  20844.595082
# 1970-01-01 00:00:00.000000003  20851.45  20932.40        NaN  20868.817615
# 1970-01-01 00:00:00.000000004  20863.05  20934.10        NaN  20899.541790
# 1970-01-01 00:00:00.000000005  20932.00  20965.30        NaN  20926.785103
# 1970-01-01 00:00:00.000000006  20867.65  21018.55        NaN  20920.107737
# 1970-01-01 00:00:00.000000007  20769.85  20929.75        NaN  20924.275409
# 1970-01-01 00:00:00.000000008  21081.10  21110.40        NaN  20986.871884
# 1970-01-01 00:00:00.000000009  21235.50  21287.45  20984.945  21090.348191
# 1970-01-01 00:00:00.000000010  21365.85  21434.80  21057.345  21160.461216
# 1970-01-01 00:00:00.000000011  21338.50  21477.65  21116.275  21221.782972
# 1970-01-01 00:00:00.000000012  21088.55  21543.50  21132.835  21196.326916
# 1970-01-01 00:00:00.000000013  20979.80  21033.95  21169.525  21214.458990
# 1970-01-01 00:00:00.000000014  21233.50  21295.85  21205.550  21238.897029
# 1970-01-01 00:00:00.000000015  21329.60  21365.20  21250.960  21283.194486
# 1970-01-01 00:00:00.000000016  21497.65  21497.65  21325.815  21358.030751
# 1970-01-01 00:00:00.000000017  21678.20  21715.00  21409.440  21442.689681
# 1970-01-01 00:00:00.000000018  21677.30  21728.90  21462.745  21500.646998
# 1970-01-01 00:00:00.000000019  21682.75  21694.25  21486.820  21538.848026

# %%
df.index=pd.to_datetime(df.index)

ema_plot=mpf.make_addplot(df['ema'],color='b')
sma_plot=mpf.make_addplot(df['sma'],color='g')

mpf.plot(df,type='candle', style='charles',volume=False, addplot=[ema_plot,sma_plot])

# %%
# Plot close price along with EMA and SMA
plt.figure(figsize=(14,7))
plt.plot(df['close'], label='Close_price', color='blue')

plt.plot(df['ema'],label='EMA', color='red', linestyle='--')
plt.plot(df['sma'],label='SMA', color='green', linestyle='--')

plt.title('Close Price with EMA and SMA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
df['ema_26']=df['close'].ewm(span=26).mean()

# %%
# demo strategy, if ema_9 crosses up ema_26, buy
# else if ema_9 crosses down ema_26, sell

# %%
# Plot close price along with EMA and SMA
plt.figure(figsize=(14,7))
plt.plot(df['close'], label='Close_price', color='blue')

plt.plot(df['ema'],label='EMA 9', color='red', linestyle='--')
plt.plot(df['ema_26'], label='EMA 26',color='green', linestyle='--')

plt.title('Close Price with EMA and SMA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
